# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/tidy/combined-dataset.csv', index_col=[0])

# %%
#g = sns.PairGrid(df, diag_sharey=False, corner=True, dropna=True)
# g.map_lower(sns.scatterplot)
# g.map_diag(sns.histplot)
# plt.savefig('../../figures/pairwise-combined.png',dpi=300)

# %%
cfc = pd.read_csv('../../data/tidy/msa-carbon-footprint.csv')
trf = pd.read_csv('../../data/tidy/tti-traffic.csv')

# %%
trf_cfc = trf.merge(cfc, left_on='msa', right_on='msa', how='left')

# %%
trf_cfc.head()
# Out:
#                       msa  auto_commuters  \
# 0               Akron, OH             298
# 1  Albany-Schenectady, NY             300
# 2         Albuquerque, NM             380
# 3        Allentown, PA-NJ             329
# 4           Anchorage, AK             137
#
#    annual_excess_fuel_consumed_commuters    ahd   tti  dvmt_freeway  \
# 0                                   6453  14470  1.11        5703.0
# 1                                   5172  13605  1.14        7273.0
# 2                                   8950  18864  1.15        5500.0
# 3                                   5627  13837  1.14        5599.0
# 4                                   2595   6193  1.17        1415.0
#
#    ahd_truck  vmt_arterial  pop_2014  electricity_kwh  ...  fueloil_gal  \
# 0        608        4460.0  678301.0     23257.037633  ...    79.046948
# 1        690        5623.0       NaN              NaN  ...          NaN
# 2        909        7887.0  729083.0     49890.513214  ...     4.024810
# 3        513        5199.0       NaN              NaN  ...          NaN
# 4        172        2240.0       NaN              NaN  ...          NaN
#
#              vmt   hh_2014  cf_transport_phh  cf_housing_phh  cf_food_phh  \
# 0   47008.858596  160668.0         15.993913       11.746599     7.517472
# 1            NaN       NaN               NaN             NaN          NaN
# 2  101942.760602  305713.0         15.594705       13.531895     7.775563
# 3            NaN       NaN               NaN             NaN          NaN
# 4            NaN       NaN               NaN             NaN          NaN
#
#    cf_goods_phh  cf_services_phh     cf_phh            cf
# 0       5.39105         6.071775  50.968122  8.188946e+06
# 1           NaN              NaN        NaN           NaN
# 2       5.05171         5.576700  49.593381  1.516134e+07
# 3           NaN              NaN        NaN           NaN
# 4           NaN              NaN        NaN           NaN
#
# [5 rows x 21 columns]

# %%
g = sns.PairGrid(trf_cfc, dropna=True)
g.map_lower(sns.scatterplot)
g.map_diag(sns.histplot)
#plt.savefig('../../figures/pairwise-combined.png',dpi=300)

# %%
f = sns.PairGrid(trf, dropna=True)
f.map_offdiag(sns.scatterplot)
f.map_diag(sns.histplot)

# %%
net = pd.read_csv('../../data/tidy/data-aggregation-networkstats.csv')

# %%
trf_net = trf.merge(net, left_on='msa', right_on='msa', how='left')

# %%
n = sns.PairGrid(trf_net, dropna=True)
n.map_lower(sns.scatterplot)
n.map_diag(sns.histplot)
