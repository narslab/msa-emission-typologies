# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data input

ems1_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q1.csv', low_memory=False) # emissions

# %%
ems2_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q2.csv', low_memory=False)

# %%
#ems3_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q3.csv')
#ems4_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q4.csv', low_memory=False)

# %%
len(ems1_df)
# Out:
# 491165

# %%
ems1_df.columns
# Out:
# Index(['# Daily air quality and meteorological measurementa for majors world-wide cities in 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
ems1_df.head()
# Out:
#   # Daily air quality and meteorological measurementa for majors world-wide cities in 2020  \
# 0  # By using this data you agree with the terms ...
# 1  # For more information check: https://aqicn.or...
# 2  # Data-Set Generated on 2020-04-13T01:04:43+01:00
# 3                                               Date
# 4                                          1/16/2019
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3    Country       City     Specie      count        min        max
# 4         AE  Abu Dhabi       pm10         24         86         99
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3     median   variance
# 4         97      179.4

# %%
ems1_df = ems1_df.set_index('Unnamed: 2')
ems1_df.index = ems1_df.index.str.replace(' ', ', ')
ems1_df = ems1_df[ems1_df['# Daily air quality and meteorological measurementa for majors world-wide cities in 2020'].str.contains('2019')]

# %%
ems1_df = ems1_df[ems1_df['Unnamed: 1'].str.contains('US')]

# %%
ems1_df
# Out:
#                # Daily air quality and meteorological measurementa for majors world-wide cities in 2020  \
# Unnamed: 2
# Oklahoma, City                                           2/9/2019
# Oklahoma, City                                          2/18/2019
# Oklahoma, City                                           3/6/2019
# Oklahoma, City                                          3/19/2019
# Oklahoma, City                                          3/23/2019
# ...                                                           ...
# Fort, Worth                                              3/9/2019
# Fort, Worth                                             1/26/2019
# Fort, Worth                                             1/28/2019
# Fort, Worth                                             1/29/2019
# Fort, Worth                                             3/26/2019
#
#                Unnamed: 1  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# Unnamed: 2
# ...

# %%
ems2_df.columns
# Out:
# Index(['# Daily air quality and meteorological measurementa for majors world-wide cities in 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
ems2_df = ems2_df.set_index('Unnamed: 2')

# %%
#ems2_df.index = ems2_df.index.str.replace(' ', ', ')

# %%
ems2_df = ems2_df[ems2_df['# Daily air quality and meteorological measurementa for majors world-wide cities in 2020'].str.contains('2019')]
ems2_df = ems2_df[ems2_df['Unnamed: 1'].str.contains('US')]

# %%
ems2_df
# Out:
#               # Daily air quality and meteorological measurementa for majors world-wide cities in 2020  \
# Unnamed: 2
# Oklahoma City                                           4/9/2019
# Oklahoma City                                          4/19/2019
# Oklahoma City                                           5/1/2019
# Oklahoma City                                           4/6/2019
# Oklahoma City                                          4/16/2019
# ...                                                          ...
# Fort Worth                                             4/26/2019
# Fort Worth                                             5/10/2019
# Fort Worth                                             5/31/2019
# Fort Worth                                             6/27/2019
# Fort Worth                                             6/28/2019
#
#               Unnamed: 1  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# Unnamed: 2
# ...

# %%
ems3_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q3.csv', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [109], in <module>
# ----> 1 ems3_df = pd.read_csv('../../data/raw/waqi-covid19-airqualitydata-2019Q3.csv', low_memory=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
