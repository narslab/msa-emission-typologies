# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data input

inc_df = pd.read_csv('../../data/raw/ACSST5Y2020.S1903_data_with_overlays_2022-04-29T132045.csv', skiprows = 1) # median income

# %%
len(inc_df)
# Out:
# 940

# %%
inc_df.columns
# Out:
# Index(['id', 'Geographic Area Name',
#        'Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households',
#        'Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households',
#        'Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White',
#        'Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White',
#        'Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American',
#        'Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American',
#        'Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native',
#        'Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native',
#        ...
#        'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone',
#        'Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone',
#        'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone',
#        'Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone',
#        'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder',
#        'Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder',
#        'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone',
#        'Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone',
#        'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone',
#        'Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone'],
#       dtype='object', length=242)

# %%
inc_df.head()
# Out:
#                id     Geographic Area Name  \
# 0  310M600US10100  Aberdeen, SD Micro Area
# 1  310M600US10140  Aberdeen, WA Micro Area
# 2  310M600US10180   Abilene, TX Metro Area
# 3  310M600US10220       Ada, OK Micro Area
# 4  310M600US10300    Adrian, MI Micro Area
#
#    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# 0                                              17795
# 1                                              29433
# 2                                              61414
# 3                                              14234
# 4                                              38693
#
#    Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# 0                                                372
# 1                                                513
# 2                                                828
# 3                                                246
# 4                                                502
#
#    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White  \
# 0                                              16134
# 1                                              26480
# 2                                              50179
# 3                                              10483
# 4                                              36729
#
#    Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White  \
# 0                                                403
# 1                                                532
# 2                                                919
# 3                                                282
# 4                                                462
#
#    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American  \
# 0                                                310
# 1                                                 69
# 2                                               3752
# 3                                                278
# 4                                                315
#
#    Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American  \
# 0                                                135
# 1                                                 45
# 2                                                303
# 3                                                 70
# 4                                                121
#
#    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native  \
# 0                                                510
# 1                                               1210
# 2                                                409
# 3                                               1802
# 4                                                114
#
#    Margin of Error!!Number!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native  \
# 0                                                187
# 1                                                210
# 2                                                142
# 3                                                180
# 4                                                 51
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone  \
# 0                                              29720
# 1                                              23330
# 2                                              23343
# 3                                              23644
# 4                                              26099
#
#    Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone  \
# 0                                               5932
# 1                                               1716
# 2                                               2686
# 3                                                835
# 4                                               2629
#
#    Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone  \
# 0                                              59009
# 1                                              47083
# 2                                              52051
# 3                                              60625
# 4                                              42750
#
#    Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone  \
# 0                                              10896
# 1                                              12913
# 2                                              16087
# 3                                              23717
# 4                                              17654
#
#    Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder  \
# 0                                              42295
# 1                                              31705
# 2                                              37639
# 3                                              31742
# 4                                              38903
#
#    Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder  \
# 0                                               6958
# 1                                               3733
# 2                                               3616
# 3                                               4102
# 4                                               2299
#
#    Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone  \
# 0                                              35366
# 1                                              28397
# 2                                              29845
# 3                                              27768
# 4                                              35356
#
#    Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone  \
# 0                                               7548
# 1                                               2449
# 2                                               5417
# 3                                               4106
# 4                                               1901
#
#    Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone  \
# 0                                              69688
# 1                                              60729
# 2                                              49266
# 3                                              46750
# 4                                              63778
#
#    Margin of Error!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone
# 0                                              10910
# 1                                              11210
# 2                                               8808
# 3                                              20976
# 4                                               9942
#
# [5 rows x 242 columns]

# %%
#pop_df.loc[: , (pop_df != 'Margin of Error').all()]
filtered_cols = [col for col in inc_df.columns if 'Margin of Error' not in col]
filtered_cols = [col for col in filtered_cols if 'Mean' not in col]
filtered_cols = [col for col in filtered_cols if 'id' not in col]
filtered_cols = [col for col in filtered_cols if 'Percent' not in col]
filtered_cols = [col for col in filtered_cols if 'Number' not in col]
filtered_cols
# Out:
# ['Geographic Area Name',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Asian',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Native Hawaiian and Other Pacific Islander',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Some other race',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!Two or more races',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!Hispanic or Latino origin (of any race)',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!White alone, not Hispanic or Latino',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!15 to 24 years',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!25 to 44 years',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!45 to 64 years',
#  'Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER!!65 years and over',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!With own children of householder under 18 years',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!With no own children of householder under 18 years',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Married-couple families',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Married-couple families!!With own children under 18 years',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Female householder, no spouse present',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Female householder, no spouse present!!With own children under 18 years',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Male householder, no spouse present',
#  'Estimate!!Median income (dollars)!!FAMILIES!!Families!!Male householder, no spouse present!!With own children under 18 years',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!2-person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!3-person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!4-person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!5-person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!6-person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY FAMILY SIZE!!7-or-more person families',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!No earners',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!1 earner',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!2 earners',
#  'Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!3 or more earners',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone',
#  'Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone']

# %%
inc_df = inc_df.filter(filtered_cols)

# %%
inc_df = inc_df.set_index('Geographic Area Name')

# %%
inc_df = inc_df.filter(like="Metro Area", axis = 0)
inc_df.index = inc_df.index.str.replace(' Metro Area', '')

# %%
# def tidy_acs_df(df):
#     #....
#     return(df)

# %%
#mods_df = tidy_acs_df(pop_df)

# %%
#inc_df = tidy_acs_df(inc_df)

# %%
inc_df.head()
# Out:
#                        Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households  \
# Geographic Area Name
# Abilene, TX                                                        54857
# Aguadilla-Isabela, PR                                              16744
# Akron, OH                                                          59313
# Albany, GA                                                         46323
# Albany-Lebanon, OR                                                 59547
#
#                        Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!White  \
# Geographic Area Name
# Abilene, TX                                                        57556
# Aguadilla-Isabela, PR                                              17088
# Akron, OH                                                          63708
# Albany, GA                                                         61806
# Albany-Lebanon, OR                                                 59841
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Black or African American  \
# Geographic Area Name
# Abilene, TX                                                        40546
# Aguadilla-Isabela, PR                                              17005
# Akron, OH                                                          33625
# Albany, GA                                                         36075
# Albany-Lebanon, OR                                                 58462
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!American Indian and Alaska Native  \
# Geographic Area Name
# Abilene, TX                                                        52944
# Aguadilla-Isabela, PR                                              19083
# Akron, OH                                                          51278
# Albany, GA                                                         39063
# Albany-Lebanon, OR                                                 42236
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Asian  \
# Geographic Area Name
# Abilene, TX                                                        58010
# Aguadilla-Isabela, PR                                              68875
# Akron, OH                                                          58147
# Albany, GA                                                         59079
# Albany-Lebanon, OR                                                 90787
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Native Hawaiian and Other Pacific Islander  \
# Geographic Area Name
# Abilene, TX                                                            -
# Aguadilla-Isabela, PR                                                  -
# Akron, OH                                                          68000
# Albany, GA                                                         53266
# Albany-Lebanon, OR                                                     -
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!One race--!!Some other race  \
# Geographic Area Name
# Abilene, TX                                                        40946
# Aguadilla-Isabela, PR                                              14921
# Akron, OH                                                          50461
# Albany, GA                                                         25795
# Albany-Lebanon, OR                                                 45058
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!Two or more races  \
# Geographic Area Name
# Abilene, TX                                                        53839
# Aguadilla-Isabela, PR                                              17826
# Akron, OH                                                          42860
# Albany, GA                                                         44886
# Albany-Lebanon, OR                                                 58679
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!Hispanic or Latino origin (of any race)  \
# Geographic Area Name
# Abilene, TX                                                        45398
# Aguadilla-Isabela, PR                                              16538
# Akron, OH                                                          45057
# Albany, GA                                                         36759
# Albany-Lebanon, OR                                                 45281
#
#                       Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households!!White alone, not Hispanic or Latino  \
# Geographic Area Name
# Abilene, TX                                                        59314
# Aguadilla-Isabela, PR                                              28337
# Akron, OH                                                          63922
# Albany, GA                                                         62302
# Albany-Lebanon, OR                                                 60425
#
#                        ...  \
# Geographic Area Name   ...
# Abilene, TX            ...
# Aguadilla-Isabela, PR  ...
# Akron, OH              ...
# Albany, GA             ...
# Albany-Lebanon, OR     ...
#
#                       Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!1 earner  \
# Geographic Area Name
# Abilene, TX                                                        47238
# Aguadilla-Isabela, PR                                              20840
# Akron, OH                                                          53964
# Albany, GA                                                         41449
# Albany-Lebanon, OR                                                 50489
#
#                        Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!2 earners  \
# Geographic Area Name
# Abilene, TX                                                        83966
# Aguadilla-Isabela, PR                                              43780
# Akron, OH                                                          96577
# Albany, GA                                                         80663
# Albany-Lebanon, OR                                                 89557
#
#                        Estimate!!Median income (dollars)!!FAMILY INCOME BY NUMBER OF EARNERS!!3 or more earners  \
# Geographic Area Name
# Abilene, TX                                                        99764
# Aguadilla-Isabela, PR                                              60065
# Akron, OH                                                         123066
# Albany, GA                                                        102184
# Albany-Lebanon, OR                                                110598
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households  \
# Geographic Area Name
# Abilene, TX                                                        30402
# Aguadilla-Isabela, PR                                               9730
# Akron, OH                                                          34665
# Albany, GA                                                         29522
# Albany-Lebanon, OR                                                 33849
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder  \
# Geographic Area Name
# Abilene, TX                                                        26385
# Aguadilla-Isabela, PR                                               8874
# Akron, OH                                                          30204
# Albany, GA                                                         25341
# Albany-Lebanon, OR                                                 27350
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Living alone  \
# Geographic Area Name
# Abilene, TX                                                        23343
# Aguadilla-Isabela, PR                                               8413
# Akron, OH                                                          26304
# Albany, GA                                                         24794
# Albany-Lebanon, OR                                                 24156
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Female householder!!Not living alone  \
# Geographic Area Name
# Abilene, TX                                                        52051
# Aguadilla-Isabela, PR                                              17027
# Akron, OH                                                          63043
# Albany, GA                                                         29178
# Albany-Lebanon, OR                                                 55750
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder  \
# Geographic Area Name
# Abilene, TX                                                        37639
# Aguadilla-Isabela, PR                                              10984
# Akron, OH                                                          40469
# Albany, GA                                                         36154
# Albany-Lebanon, OR                                                 40989
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Living alone  \
# Geographic Area Name
# Abilene, TX                                                        29845
# Aguadilla-Isabela, PR                                              10267
# Akron, OH                                                          35683
# Albany, GA                                                         33923
# Albany-Lebanon, OR                                                 37579
#
#                        Estimate!!Median income (dollars)!!NONFAMILY HOUSEHOLDS!!Nonfamily households!!Male householder!!Not living alone
# Geographic Area Name
# Abilene, TX                                                        49266
# Aguadilla-Isabela, PR                                              17029
# Akron, OH                                                          66258
# Albany, GA                                                         58106
# Albany-Lebanon, OR                                                 57857
#
# [5 rows x 40 columns]

# %%
med_income = inc_df['Estimate!!Median income (dollars)!!HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER!!Households']
