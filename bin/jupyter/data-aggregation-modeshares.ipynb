# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data input

mods_df = pd.read_csv('../../data/raw/ACSDT5Y2014.B08006-Data.csv', skiprows=1) # modeshares (for commuting)

# %%
len(mods_df)
mods_df.head()
# Out:
#         Geography     Geographic Area Name  Estimate!!Total  \
# 0  310M200US10100  Aberdeen, SD Micro Area            22490
# 1  310M200US10140  Aberdeen, WA Micro Area            25472
# 2  310M200US10180   Abilene, TX Metro Area            72274
# 3  310M200US10220       Ada, OK Micro Area            16976
# 4  310M200US10260  Adjuntas, PR Micro Area             4202
#
#    Margin of Error!!Total  Annotation of Margin of Error!!Total  \
# 0                     438                                   NaN
# 1                     851                                   NaN
# 2                    2110                                   NaN
# 3                     474                                   NaN
# 4                     326                                   NaN
#
#    Annotation of Estimate!!Total  Estimate!!Total!!Car, truck, or van  \
# 0                            NaN                                20217
# 1                            NaN                                22677
# 2                            NaN                                66762
# 3                            NaN                                15804
# 4                            NaN                                 3856
#
#    Margin of Error!!Total!!Car, truck, or van  \
# 0                                         469
# 1                                         913
# 2                                        2119
# 3                                         465
# 4                                         313
#
#    Annotation of Margin of Error!!Total!!Car, truck, or van  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annotation of Estimate!!Total!!Car, truck, or van  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#    Annotation of Estimate!!Total!!Female!!Walked  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Estimate!!Total!!Female!!Taxicab, motorcycle, or other means  \
# 0                                                233
# 1                                                138
# 2                                                528
# 3                                                 50
# 4                                                  0
#
#    Margin of Error!!Total!!Female!!Taxicab, motorcycle, or other means  \
# 0                                                124
# 1                                                 86
# 2                                                195
# 3                                                 35
# 4                                                 20
#
#    Annotation of Margin of Error!!Total!!Female!!Taxicab, motorcycle, or other means  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annotation of Estimate!!Total!!Female!!Taxicab, motorcycle, or other means  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Estimate!!Total!!Female!!Worked at home  \
# 0                                      328
# 1                                      736
# 2                                      787
# 3                                      190
# 4                                       17
#
#    Margin of Error!!Total!!Female!!Worked at home  \
# 0                                              88
# 1                                             170
# 2                                             145
# 3                                              65
# 4                                              24
#
#    Annotation of Margin of Error!!Total!!Female!!Worked at home  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Annotation of Estimate!!Total!!Female!!Worked at home  Unnamed: 206
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
# [5 rows x 207 columns]

# %%
mods_df.columns
# Out:
# Index(['Geography', 'Geographic Area Name', 'Estimate!!Total',
#        'Margin of Error!!Total', 'Annotation of Margin of Error!!Total',
#        'Annotation of Estimate!!Total', 'Estimate!!Total!!Car, truck, or van',
#        'Margin of Error!!Total!!Car, truck, or van',
#        'Annotation of Margin of Error!!Total!!Car, truck, or van',
#        'Annotation of Estimate!!Total!!Car, truck, or van',
#        ...
#        'Annotation of Estimate!!Total!!Female!!Walked',
#        'Estimate!!Total!!Female!!Taxicab, motorcycle, or other means',
#        'Margin of Error!!Total!!Female!!Taxicab, motorcycle, or other means',
#        'Annotation of Margin of Error!!Total!!Female!!Taxicab, motorcycle, or other means',
#        'Annotation of Estimate!!Total!!Female!!Taxicab, motorcycle, or other means',
#        'Estimate!!Total!!Female!!Worked at home',
#        'Margin of Error!!Total!!Female!!Worked at home',
#        'Annotation of Margin of Error!!Total!!Female!!Worked at home',
#        'Annotation of Estimate!!Total!!Female!!Worked at home',
#        'Unnamed: 206'],
#       dtype='object', length=207)

# %%
#pop_df.loc[: , (pop_df != 'Margin of Error').all()]
filtered_cols = [col for col in mods_df.columns if 'Margin of Error' not in col]
filtered_cols = [col for col in filtered_cols if 'Male' not in col]
filtered_cols = [col for col in filtered_cols if 'Female' not in col]
filtered_cols = [col for col in filtered_cols if 'Annotation' not in col]
filtered_cols = [col for col in filtered_cols if 'Unnamed' not in col]
filtered_cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Estimate!!Total',
#  'Estimate!!Total!!Car, truck, or van',
#  'Estimate!!Total!!Car, truck, or van!!Drove alone',
#  'Estimate!!Total!!Car, truck, or van!!Carpooled',
#  'Estimate!!Total!!Car, truck, or van!!Carpooled!!In 2-person carpool',
#  'Estimate!!Total!!Car, truck, or van!!Carpooled!!In 3-person carpool',
#  'Estimate!!Total!!Car, truck, or van!!Carpooled!!In 4-or-more-person carpool',
#  'Estimate!!Total!!Public transportation (excluding taxicab)',
#  'Estimate!!Total!!Public transportation (excluding taxicab)!!Bus or trolley bus',
#  'Estimate!!Total!!Public transportation (excluding taxicab)!!Streetcar or trolley car (carro publico in Puerto Rico)',
#  'Estimate!!Total!!Public transportation (excluding taxicab)!!Subway or elevated',
#  'Estimate!!Total!!Public transportation (excluding taxicab)!!Railroad',
#  'Estimate!!Total!!Public transportation (excluding taxicab)!!Ferryboat',
#  'Estimate!!Total!!Bicycle',
#  'Estimate!!Total!!Walked',
#  'Estimate!!Total!!Taxicab, motorcycle, or other means',
#  'Estimate!!Total!!Worked at home']

# %%
mods_df = mods_df.filter(filtered_cols)
mods_df = mods_df.set_index('Geographic Area Name')
mods_df = mods_df.filter(like="Metro Area", axis=0)
mods_df.index = mods_df.index.str.replace(' Metro Area', '')

# %%
# def tidy_acs_df(df):
#     #....
#     return(df)

# %%
#mods_df = tidy_acs_df(pop_df)

# %%
#inc_df = tidy_acs_df(inc_df)

# %%
mods_df.head()
# Out:
#                             Geography  Estimate!!Total  \
# Geographic Area Name
# Abilene, TX            310M200US10180            72274
# Aguadilla-Isabela, PR  310M200US10380            77004
# Akron, OH              310M200US10420           329396
# Albany, GA             310M200US10500            59078
# Albany, OR             310M200US10540            47276
#
#                        Estimate!!Total!!Car, truck, or van  \
# Geographic Area Name
# Abilene, TX                                          66762
# Aguadilla-Isabela, PR                                71260
# Akron, OH                                           306252
# Albany, GA                                           54802
# Albany, OR                                           41872
#
#                        Estimate!!Total!!Car, truck, or van!!Drove alone  \
# Geographic Area Name
# Abilene, TX                                                       58286
# Aguadilla-Isabela, PR                                             64807
# Akron, OH                                                        284185
# Albany, GA                                                        47511
# Albany, OR                                                        36575
#
#                        Estimate!!Total!!Car, truck, or van!!Carpooled  \
# Geographic Area Name
# Abilene, TX                                                      8476
# Aguadilla-Isabela, PR                                            6453
# Akron, OH                                                       22067
# Albany, GA                                                       7291
# Albany, OR                                                       5297
#
#                        Estimate!!Total!!Car, truck, or van!!Carpooled!!In 2-person carpool  \
# Geographic Area Name
# Abilene, TX                                                         6553
# Aguadilla-Isabela, PR                                               4137
# Akron, OH                                                          18215
# Albany, GA                                                          5387
# Albany, OR                                                          4060
#
#                        Estimate!!Total!!Car, truck, or van!!Carpooled!!In 3-person carpool  \
# Geographic Area Name
# Abilene, TX                                                          970
# Aguadilla-Isabela, PR                                               1415
# Akron, OH                                                           2208
# Albany, GA                                                          1270
# Albany, OR                                                           684
#
#                        Estimate!!Total!!Car, truck, or van!!Carpooled!!In 4-or-more-person carpool  \
# Geographic Area Name
# Abilene, TX                                                          953
# Aguadilla-Isabela, PR                                                901
# Akron, OH                                                           1644
# Albany, GA                                                           634
# Albany, OR                                                           553
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)  \
# Geographic Area Name
# Abilene, TX                                                          464
# Aguadilla-Isabela, PR                                                275
# Akron, OH                                                           4934
# Albany, GA                                                           636
# Albany, OR                                                           276
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)!!Bus or trolley bus  \
# Geographic Area Name
# Abilene, TX                                                          464
# Aguadilla-Isabela, PR                                                 93
# Akron, OH                                                           4907
# Albany, GA                                                           636
# Albany, OR                                                           233
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)!!Streetcar or trolley car (carro publico in Puerto Rico)  \
# Geographic Area Name
# Abilene, TX                                                            0
# Aguadilla-Isabela, PR                                                150
# Akron, OH                                                             11
# Albany, GA                                                             0
# Albany, OR                                                             0
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)!!Subway or elevated  \
# Geographic Area Name
# Abilene, TX                                                            0
# Aguadilla-Isabela, PR                                                 32
# Akron, OH                                                             12
# Albany, GA                                                             0
# Albany, OR                                                             2
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)!!Railroad  \
# Geographic Area Name
# Abilene, TX                                                            0
# Aguadilla-Isabela, PR                                                  0
# Akron, OH                                                              4
# Albany, GA                                                             0
# Albany, OR                                                            31
#
#                        Estimate!!Total!!Public transportation (excluding taxicab)!!Ferryboat  \
# Geographic Area Name
# Abilene, TX                                                            0
# Aguadilla-Isabela, PR                                                  0
# Akron, OH                                                              0
# Albany, GA                                                             0
# Albany, OR                                                            10
#
#                        Estimate!!Total!!Bicycle  Estimate!!Total!!Walked  \
# Geographic Area Name
# Abilene, TX                                 151                     1737
# Aguadilla-Isabela, PR                       144                     3251
# Akron, OH                                   437                     5550
# Albany, GA                                   88                     1159
# Albany, OR                                  626                     1089
#
#                        Estimate!!Total!!Taxicab, motorcycle, or other means  \
# Geographic Area Name
# Abilene, TX                                                         1275
# Aguadilla-Isabela, PR                                                305
# Akron, OH                                                           1656
# Albany, GA                                                           469
# Albany, OR                                                           526
#
#                        Estimate!!Total!!Worked at home
# Geographic Area Name
# Abilene, TX                                       1885
# Aguadilla-Isabela, PR                             1769
# Akron, OH                                        10567
# Albany, GA                                        1924
# Albany, OR                                        2887

# %%
mods_df['Estimate!!Total!!Car, truck, or van!!Drove alone']/mods_df['Estimate!!Total!!Car, truck, or van']
# Out:
# Geographic Area Name
# Abilene, TX                          0.873042
# Aguadilla-Isabela, PR                0.909444
# Akron, OH                            0.927945
# Albany, GA                           0.866957
# Albany, OR                           0.873495
#                                        ...
# Yakima, WA                           0.853660
# York-Hanover, PA                     0.915019
# Youngstown-Warren-Boardman, OH-PA    0.921333
# Yuba City, CA                        0.838439
# Yuma, AZ                             0.855864
# Length: 388, dtype: float64

# %%
### Create empty dataframe with ACS MSA names as index:
ms_df = pd.DataFrame(index = mods_df.index)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: [Abilene, TX, Aguadilla-Isabela, PR, Akron, OH, Albany, GA, Albany, OR]

# %%
ms_df.insert(loc = 0, column = 'ms_cara', value = mods_df['Estimate!!Total!!Car, truck, or van!!Drove alone']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 1, column = 'ms_carp', value = mods_df['Estimate!!Total!!Car, truck, or van!!Carpooled']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 2, column = 'ms_pt', value = mods_df['Estimate!!Total!!Public transportation (excluding taxicab)']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 3, column = 'ms_taxi', value = mods_df['Estimate!!Total!!Taxicab, motorcycle, or other means']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 4, column = 'ms_bike', value = mods_df['Estimate!!Total!!Bicycle']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 5, column = 'ms_walk', value = mods_df['Estimate!!Total!!Walked']/mods_df['Estimate!!Total'])
ms_df.insert(loc = 6, column = 'ms_wfh', value = mods_df['Estimate!!Total!!Worked at home']/mods_df['Estimate!!Total'])

# %%
ms_df.head()
# Out:
#                         ms_cara   ms_carp     ms_pt   ms_taxi   ms_bike  \
# Geographic Area Name
# Abilene, TX            0.806459  0.117276  0.006420  0.017641  0.002089
# Aguadilla-Isabela, PR  0.841606  0.083801  0.003571  0.003961  0.001870
# Akron, OH              0.862746  0.066992  0.014979  0.005027  0.001327
# Albany, GA             0.804208  0.123413  0.010765  0.007939  0.001490
# Albany, OR             0.773648  0.112044  0.005838  0.011126  0.013241
#
#                         ms_walk    ms_wfh
# Geographic Area Name
# Abilene, TX            0.024034  0.026081
# Aguadilla-Isabela, PR  0.042219  0.022973
# Akron, OH              0.016849  0.032080
# Albany, GA             0.019618  0.032567
# Albany, OR             0.023035  0.061067

# %%
ms_df.sum(axis=1)
# Out:
# Geographic Area Name
# Abilene, TX                          1.0
# Aguadilla-Isabela, PR                1.0
# Akron, OH                            1.0
# Albany, GA                           1.0
# Albany, OR                           1.0
#                                     ...
# Yakima, WA                           1.0
# York-Hanover, PA                     1.0
# Youngstown-Warren-Boardman, OH-PA    1.0
# Yuba City, CA                        1.0
# Yuma, AZ                             1.0
# Length: 388, dtype: float64

# %%
#mods_df.to_csv('data-aggregation-modeshares.csv', index = False)
from pathlib import Path  
filepath = Path('../../data/tidy/data-aggregation-modeshares.csv', index = False)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
mods_df.to_csv(filepath)

# %%
from pathlib import Path  
filepath = Path('../../data/tidy/data-aggregation-ms.csv', index = False)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
ms_df.to_csv(filepath)
