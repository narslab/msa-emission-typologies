# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data input
pop_df = pd.read_csv('../../data/raw/ACSST5Y2014.S2301-Data.csv', skiprows = 1) # population and employment rate

# %%
pop_df
# Out:
#           Geography                          Geographic Area Name  \
# 0    310M200US10100                       Aberdeen, SD Micro Area
# 1    310M200US10140                       Aberdeen, WA Micro Area
# 2    310M200US10180                        Abilene, TX Metro Area
# 3    310M200US10220                            Ada, OK Micro Area
# 4    310M200US10260                       Adjuntas, PR Micro Area
# ..              ...                                           ...
# 924  310M200US49660  Youngstown-Warren-Boardman, OH-PA Metro Area
# 925  310M200US49700                      Yuba City, CA Metro Area
# 926  310M200US49740                           Yuma, AZ Metro Area
# 927  310M200US49780                     Zanesville, OH Micro Area
# 928  310M200US49820                         Zapata, TX Micro Area
#
#      Total!!Estimate!!Population 16 years and over  \
# 0                                            33087
# 1                                            58275
# 2                                           131984
# 3                                            29870
# 4                                            15080
# ..                                             ...
# 924                                         456448
# 925                                         126841
# 926                                         153342
# 927                                          68178
# 928                                           9868
#
#      Annotation of Total!!Estimate!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      Total!!Margin of Error!!Population 16 years and over  \
# 0                                                  189
# 1                                                  191
# 2                                                  239
# 3                                                   95
# 4                                                   88
# ..                                                 ...
# 924                                                413
# 925                                                306
# 926                                                341
# 927                                                179
# 928                                                150
#
#      Annotation of Total!!Margin of Error!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      In labor force!!Estimate!!Population 16 years and over  \
# 0                                                 70.6
# 1                                                 52.8
# 2                                                 59.3
# 3                                                 62.2
# 4                                                 42.4
# ..                                                 ...
# 924                                               57.9
# 925                                               59.8
# 926                                               55.3
# 927                                               60.0
# 928                                               57.6
#
#      In labor force!!Margin of Error!!Population 16 years and over  \
# 0                                                  1.3
# 1                                                  1.3
# 2                                                  1.7
# 3                                                  1.5
# 4                                                  2.3
# ..                                                 ...
# 924                                                0.4
# 925                                                0.9
# 926                                                0.9
# 927                                                1.2
# 928                                                3.6
#
#      Annotation of In labor force!!Margin of Error!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      Annotation of In labor force!!Estimate!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 924  ...
# 925  ...
# 926  ...
# 927  ...
# 928  ...
#
#      Annotation of In labor force!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unnamed: 482
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 924           NaN
# 925           NaN
# 926           NaN
# 927           NaN
# 928           NaN
#
# [929 rows x 483 columns]

# %%
len(pop_df)
# Out:
# 929

# %%
pop_df.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Total!!Estimate!!Population 16 years and over',
#        'Annotation of Total!!Estimate!!Population 16 years and over',
#        'Total!!Margin of Error!!Population 16 years and over',
#        'Annotation of Total!!Margin of Error!!Population 16 years and over',
#        'In labor force!!Estimate!!Population 16 years and over',
#        'In labor force!!Margin of Error!!Population 16 years and over',
#        'Annotation of In labor force!!Margin of Error!!Population 16 years and over',
#        'Annotation of In labor force!!Estimate!!Population 16 years and over',
#        ...
#        'Annotation of In labor force!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unnamed: 482'],
#       dtype='object', length=483)

# %%
#pop_df.loc[: , (pop_df != 'Margin of Error').all()]
filtered_cols = [col for col in pop_df.columns if 'Margin of Error' not in col]
filtered_cols = [col for col in filtered_cols if 'SEX' not in col]
filtered_cols = [col for col in filtered_cols if 'RACE' not in col]
filtered_cols = [col for col in filtered_cols if 'Percent' not in col]
filtered_cols = [col for col in filtered_cols if 'PERCENT' not in col]
filtered_cols = [col for col in filtered_cols if 'Annotation' not in col]
filtered_cols = [col for col in filtered_cols if 'Unnamed' not in col]
filtered_cols = [col for col in filtered_cols if 'EDUCATIONAL' not in col]
filtered_cols = [col for col in filtered_cols if 'DISABILITY' not in col]
filtered_cols = [col for col in filtered_cols if 'White' not in col]
filtered_cols = [col for col in filtered_cols if 'race' not in col]
filtered_cols = [col for col in filtered_cols if 'AGE' not in col]
filtered_cols = [col for col in filtered_cols if 'POVERTY' not in col]
filtered_cols = [col for col in filtered_cols if '20' not in col]
filtered_cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Total!!Estimate!!Population 16 years and over',
#  'In labor force!!Estimate!!Population 16 years and over',
#  'Employed!!Estimate!!Population 16 years and over',
#  'Unemployment rate!!Estimate!!Population 16 years and over']

# %%
#len(pop_df)

# %%
pop_df = pop_df.filter(filtered_cols)

# %%
pop_df.head()
# Out:
#         Geography     Geographic Area Name  \
# 0  310M200US10100  Aberdeen, SD Micro Area
# 1  310M200US10140  Aberdeen, WA Micro Area
# 2  310M200US10180   Abilene, TX Metro Area
# 3  310M200US10220       Ada, OK Micro Area
# 4  310M200US10260  Adjuntas, PR Micro Area
#
#    Total!!Estimate!!Population 16 years and over  \
# 0                                          33087
# 1                                          58275
# 2                                         131984
# 3                                          29870
# 4                                          15080
#
#    In labor force!!Estimate!!Population 16 years and over  \
# 0                                               70.6
# 1                                               52.8
# 2                                               59.3
# 3                                               62.2
# 4                                               42.4
#
#    Employed!!Estimate!!Population 16 years and over  \
# 0                                              68.7
# 1                                              44.8
# 2                                              53.3
# 3                                              58.0
# 4                                              28.0
#
#    Unemployment rate!!Estimate!!Population 16 years and over
# 0                                                2.4
# 1                                               15.0
# 2                                                6.4
# 3                                                6.8
# 4                                               34.0

# %%
pop_df = pop_df.set_index('Geographic Area Name')
pop_df = pop_df.filter(like="Metro Area", axis = 0)
pop_df.index = pop_df.index.str.replace(' Metro Area', '')

# %%
pop_df.head()
# Out:
#                             Geography  \
# Geographic Area Name
# Abilene, TX            310M200US10180
# Aguadilla-Isabela, PR  310M200US10380
# Akron, OH              310M200US10420
# Albany, GA             310M200US10500
# Albany, OR             310M200US10540
#
#                        Total!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                   131984
# Aguadilla-Isabela, PR                                         265643
# Akron, OH                                                     570055
# Albany, GA                                                    121559
# Albany, OR                                                     93268
#
#                        In labor force!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                         59.3
# Aguadilla-Isabela, PR                                               40.1
# Akron, OH                                                           65.5
# Albany, GA                                                          58.3
# Albany, OR                                                          58.1
#
#                        Employed!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                        53.3
# Aguadilla-Isabela, PR                                              30.0
# Akron, OH                                                          59.1
# Albany, GA                                                         49.3
# Albany, OR                                                         51.5
#
#                        Unemployment rate!!Estimate!!Population 16 years and over
# Geographic Area Name
# Abilene, TX                                                          6.4
# Aguadilla-Isabela, PR                                               25.2
# Akron, OH                                                            9.7
# Albany, GA                                                          15.0
# Albany, OR                                                          11.2

# %%
### Create empty dataframe with ACS MSA names as index:
#po_df = pd.DataFrame(index = pop_df.index)

# %%
employment_rate = pop_df['Employed!!Estimate!!Population 16 years and over']/pop_df['In labor force!!Estimate!!Population 16 years and over']

# %%
employment_rate
# Out:
# Geographic Area Name
# Abilene, TX                          0.898820
# Aguadilla-Isabela, PR                0.748130
# Akron, OH                            0.902290
# Albany, GA                           0.845626
# Albany, OR                           0.886403
#                                        ...
# Yakima, WA                           0.898387
# York-Hanover, PA                     0.915430
# Youngstown-Warren-Boardman, OH-PA    0.903282
# Yuba City, CA                        0.819398
# Yuma, AZ                             0.831826
# Length: 388, dtype: float64

# %%
unemployment_rate_check = (1 - employment_rate)*100

# %%
unemployment_rate_check
# Out:
# Geographic Area Name
# Abilene, TX                          10.118044
# Aguadilla-Isabela, PR                25.187032
# Akron, OH                             9.770992
# Albany, GA                           15.437393
# Albany, OR                           11.359725
#                                        ...
# Yakima, WA                           10.161290
# York-Hanover, PA                      8.456973
# Youngstown-Warren-Boardman, OH-PA     9.671848
# Yuba City, CA                        18.060201
# Yuma, AZ                             16.817360
# Length: 388, dtype: float64

# %%
#SLightly matches unemployment check?

unemployment_rate = pop_df['Unemployment rate!!Estimate!!Population 16 years and over']

# %%
unemployment_rate
# Out:
# Geographic Area Name
# Abilene, TX                           6.4
# Aguadilla-Isabela, PR                25.2
# Akron, OH                             9.7
# Albany, GA                           15.0
# Albany, OR                           11.2
#                                      ...
# Yakima, WA                           10.0
# York-Hanover, PA                      8.3
# Youngstown-Warren-Boardman, OH-PA     9.4
# Yuba City, CA                        15.4
# Yuma, AZ                             13.4
# Name: Unemployment rate!!Estimate!!Population 16 years and over, Length: 388, dtype: float64

# %%
filtered_cols = [col for col in filtered_cols if 'Employed' not in col]
filtered_cols = [col for col in filtered_cols if 'labor' not in col]
filtered_cols = [col for col in filtered_cols if 'Total' not in col]
filtered_cols = [col for col in filtered_cols if 'Geography' not in col]
filtered_cols
# Out:
# ['Geographic Area Name',
#  'Unemployment rate!!Estimate!!Population 16 years and over']

# %%
pop_df = pop_df.filter(filtered_cols)

# %%
pop_df.head()
# Out:
#                        Unemployment rate!!Estimate!!Population 16 years and over
# Geographic Area Name
# Abilene, TX                                                          6.4
# Aguadilla-Isabela, PR                                               25.2
# Akron, OH                                                            9.7
# Albany, GA                                                          15.0
# Albany, OR                                                          11.2

# %%
pop_df = pop_df.rename(columns = {"Unemployment rate!!Estimate!!Population 16 years and over": "unemp"})

# %%
pop_df.head()
# Out:
#                        unemp
# Geographic Area Name
# Abilene, TX              6.4
# Aguadilla-Isabela, PR   25.2
# Akron, OH                9.7
# Albany, GA              15.0
# Albany, OR              11.2

# %%
#pop_df.to_csv('data-aggregation-pop.csv', index = False)
from pathlib import Path  
filepath = Path('../../data/tidy/data-aggregation-pop.csv', index = False)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
pop_df.to_csv(filepath)
