# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
### Data input
pop_df = pd.read_csv('../../data/raw/ACSST5Y2014.S2301-Data.csv', skiprows = 1) # population and employment rate

# %%
pop_df
# Out:
#           Geography                          Geographic Area Name  \
# 0    310M200US10100                       Aberdeen, SD Micro Area
# 1    310M200US10140                       Aberdeen, WA Micro Area
# 2    310M200US10180                        Abilene, TX Metro Area
# 3    310M200US10220                            Ada, OK Micro Area
# 4    310M200US10260                       Adjuntas, PR Micro Area
# ..              ...                                           ...
# 924  310M200US49660  Youngstown-Warren-Boardman, OH-PA Metro Area
# 925  310M200US49700                      Yuba City, CA Metro Area
# 926  310M200US49740                           Yuma, AZ Metro Area
# 927  310M200US49780                     Zanesville, OH Micro Area
# 928  310M200US49820                         Zapata, TX Micro Area
#
#      Total!!Estimate!!Population 16 years and over  \
# 0                                            33087
# 1                                            58275
# 2                                           131984
# 3                                            29870
# 4                                            15080
# ..                                             ...
# 924                                         456448
# 925                                         126841
# 926                                         153342
# 927                                          68178
# 928                                           9868
#
#      Annotation of Total!!Estimate!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      Total!!Margin of Error!!Population 16 years and over  \
# 0                                                  189
# 1                                                  191
# 2                                                  239
# 3                                                   95
# 4                                                   88
# ..                                                 ...
# 924                                                413
# 925                                                306
# 926                                                341
# 927                                                179
# 928                                                150
#
#      Annotation of Total!!Margin of Error!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      In labor force!!Estimate!!Population 16 years and over  \
# 0                                                 70.6
# 1                                                 52.8
# 2                                                 59.3
# 3                                                 62.2
# 4                                                 42.4
# ..                                                 ...
# 924                                               57.9
# 925                                               59.8
# 926                                               55.3
# 927                                               60.0
# 928                                               57.6
#
#      In labor force!!Margin of Error!!Population 16 years and over  \
# 0                                                  1.3
# 1                                                  1.3
# 2                                                  1.7
# 3                                                  1.5
# 4                                                  2.3
# ..                                                 ...
# 924                                                0.4
# 925                                                0.9
# 926                                                0.9
# 927                                                1.2
# 928                                                3.6
#
#      Annotation of In labor force!!Margin of Error!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      Annotation of In labor force!!Estimate!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 924  ...
# 925  ...
# 926  ...
# 927  ...
# 928  ...
#
#      Annotation of In labor force!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Annotation of Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over  \
# 0                                                  (X)
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 924                                                (X)
# 925                                                (X)
# 926                                                (X)
# 927                                                (X)
# 928                                                (X)
#
#      Unnamed: 482
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 924           NaN
# 925           NaN
# 926           NaN
# 927           NaN
# 928           NaN
#
# [929 rows x 483 columns]

# %%
len(pop_df)
# Out:
# 929

# %%
pop_df.columns
# Out:
# Index(['Geography', 'Geographic Area Name',
#        'Total!!Estimate!!Population 16 years and over',
#        'Annotation of Total!!Estimate!!Population 16 years and over',
#        'Total!!Margin of Error!!Population 16 years and over',
#        'Annotation of Total!!Margin of Error!!Population 16 years and over',
#        'In labor force!!Estimate!!Population 16 years and over',
#        'In labor force!!Margin of Error!!Population 16 years and over',
#        'Annotation of In labor force!!Margin of Error!!Population 16 years and over',
#        'Annotation of In labor force!!Estimate!!Population 16 years and over',
#        ...
#        'Annotation of In labor force!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Employed!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Employed!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Unemployment rate!!Margin of Error!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Annotation of Unemployment rate!!Estimate!!PERCENT IMPUTED!!Employment status for population 16 years and over',
#        'Unnamed: 482'],
#       dtype='object', length=483)

# %%
#pop_df.loc[: , (pop_df != 'Margin of Error').all()]
filtered_cols = [col for col in pop_df.columns if 'Margin of Error' not in col]
filtered_cols = [col for col in filtered_cols if 'SEX' not in col]
filtered_cols = [col for col in filtered_cols if 'RACE' not in col]
filtered_cols = [col for col in filtered_cols if 'Percent' not in col]
filtered_cols = [col for col in filtered_cols if 'PERCENT' not in col]
filtered_cols = [col for col in filtered_cols if 'Annotation' not in col]
filtered_cols = [col for col in filtered_cols if 'Unnamed' not in col]
filtered_cols = [col for col in filtered_cols if 'EDUCATIONAL' not in col]
filtered_cols = [col for col in filtered_cols if 'DISABILITY' not in col]
filtered_cols = [col for col in filtered_cols if 'White' not in col]
filtered_cols = [col for col in filtered_cols if 'race' not in col]
filtered_cols
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Total!!Estimate!!Population 16 years and over',
#  'In labor force!!Estimate!!Population 16 years and over',
#  'Employed!!Estimate!!Population 16 years and over',
#  'Unemployment rate!!Estimate!!Population 16 years and over',
#  'Total!!Estimate!!AGE!!16 to 19 years',
#  'In labor force!!Estimate!!AGE!!16 to 19 years',
#  'Employed!!Estimate!!AGE!!16 to 19 years',
#  'Unemployment rate!!Estimate!!AGE!!16 to 19 years',
#  'Total!!Estimate!!AGE!!20 to 24 years',
#  'In labor force!!Estimate!!AGE!!20 to 24 years',
#  'Employed!!Estimate!!AGE!!20 to 24 years',
#  'Unemployment rate!!Estimate!!AGE!!20 to 24 years',
#  'Total!!Estimate!!AGE!!25 to 44 years',
#  'In labor force!!Estimate!!AGE!!25 to 44 years',
#  'Employed!!Estimate!!AGE!!25 to 44 years',
#  'Unemployment rate!!Estimate!!AGE!!25 to 44 years',
#  'Total!!Estimate!!AGE!!45 to 54 years',
#  'In labor force!!Estimate!!AGE!!45 to 54 years',
#  'Employed!!Estimate!!AGE!!45 to 54 years',
#  'Unemployment rate!!Estimate!!AGE!!45 to 54 years',
#  'Total!!Estimate!!AGE!!55 to 64 years',
#  'In labor force!!Estimate!!AGE!!55 to 64 years',
#  'Employed!!Estimate!!AGE!!55 to 64 years',
#  'Unemployment rate!!Estimate!!AGE!!55 to 64 years',
#  'Total!!Estimate!!AGE!!65 to 74 years',
#  'In labor force!!Estimate!!AGE!!65 to 74 years',
#  'Employed!!Estimate!!AGE!!65 to 74 years',
#  'Unemployment rate!!Estimate!!AGE!!65 to 74 years',
#  'Total!!Estimate!!AGE!!75 years and over',
#  'In labor force!!Estimate!!AGE!!75 years and over',
#  'Employed!!Estimate!!AGE!!75 years and over',
#  'Unemployment rate!!Estimate!!AGE!!75 years and over',
#  'Total!!Estimate!!Population 20 to 64 years',
#  'In labor force!!Estimate!!Population 20 to 64 years',
#  'Employed!!Estimate!!Population 20 to 64 years',
#  'Unemployment rate!!Estimate!!Population 20 to 64 years',
#  'Total!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level',
#  'In labor force!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level',
#  'Employed!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level',
#  'Unemployment rate!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level']

# %%
#len(pop_df)

# %%
pop_df = pop_df.filter(filtered_cols)

# %%
pop_df.head()
# Out:
#         Geography     Geographic Area Name  \
# 0  310M200US10100  Aberdeen, SD Micro Area
# 1  310M200US10140  Aberdeen, WA Micro Area
# 2  310M200US10180   Abilene, TX Metro Area
# 3  310M200US10220       Ada, OK Micro Area
# 4  310M200US10260  Adjuntas, PR Micro Area
#
#    Total!!Estimate!!Population 16 years and over  \
# 0                                          33087
# 1                                          58275
# 2                                         131984
# 3                                          29870
# 4                                          15080
#
#    In labor force!!Estimate!!Population 16 years and over  \
# 0                                               70.6
# 1                                               52.8
# 2                                               59.3
# 3                                               62.2
# 4                                               42.4
#
#    Employed!!Estimate!!Population 16 years and over  \
# 0                                              68.7
# 1                                              44.8
# 2                                              53.3
# 3                                              58.0
# 4                                              28.0
#
#    Unemployment rate!!Estimate!!Population 16 years and over  \
# 0                                                2.4
# 1                                               15.0
# 2                                                6.4
# 3                                                6.8
# 4                                               34.0
#
#    Total!!Estimate!!AGE!!16 to 19 years  \
# 0                                  2483
# 1                                  3273
# 2                                 10188
# 3                                  2252
# 4                                  1128
#
#    In labor force!!Estimate!!AGE!!16 to 19 years  \
# 0                                           55.7
# 1                                           40.6
# 2                                           41.2
# 3                                           44.9
# 4                                           12.1
#
#    Employed!!Estimate!!AGE!!16 to 19 years  \
# 0                                     51.3
# 1                                     27.1
# 2                                     33.0
# 3                                     36.1
# 4                                      0.0
#
#    Unemployment rate!!Estimate!!AGE!!16 to 19 years  ...  \
# 0                                               7.9  ...
# 1                                              33.3  ...
# 2                                              18.0  ...
# 3                                              19.6  ...
# 4                                             100.0  ...
#
#    Employed!!Estimate!!AGE!!75 years and over  \
# 0                                        10.1
# 1                                         5.1
# 2                                         8.1
# 3                                         8.5
# 4                                         6.4
#
#    Unemployment rate!!Estimate!!AGE!!75 years and over  \
# 0                                                1.1
# 1                                                4.1
# 2                                                1.5
# 3                                                0.0
# 4                                                5.1
#
#    Total!!Estimate!!Population 20 to 64 years  \
# 0                                       23808
# 1                                       42475
# 2                                       98352
# 3                                       21854
# 4                                       11120
#
#    In labor force!!Estimate!!Population 20 to 64 years  \
# 0                                               85.9
# 1                                               65.8
# 2                                               70.9
# 3                                               75.6
# 4                                               55.0
#
#    Employed!!Estimate!!Population 20 to 64 years  \
# 0                                           83.7
# 1                                           56.2
# 2                                           63.8
# 3                                           70.6
# 4                                           36.6
#
#    Unemployment rate!!Estimate!!Population 20 to 64 years  \
# 0                                                2.2
# 1                                               14.4
# 2                                                6.0
# 3                                                6.5
# 4                                               33.3
#
#    Total!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# 0                                               2365
# 1                                               7362
# 2                                              15289
# 3                                               3980
# 4                                               6555
#
#    In labor force!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# 0                                               65.5
# 1                                               45.0
# 2                                               52.3
# 3                                               54.5
# 4                                               43.5
#
#    Employed!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# 0                                               59.5
# 1                                               29.1
# 2                                               41.7
# 3                                               43.7
# 4                                               18.4
#
#    Unemployment rate!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level
# 0                                                9.2
# 1                                               35.1
# 2                                               19.6
# 3                                               19.9
# 4                                               57.6
#
# [5 rows x 42 columns]

# %%
pop_df = pop_df.set_index('Geographic Area Name')
pop_df = pop_df.filter(like="Metro Area", axis = 0)
pop_df.index = pop_df.index.str.replace(' Metro Area', '')

# %%
pop_df.head()
# Out:
#                             Geography  \
# Geographic Area Name
# Abilene, TX            310M200US10180
# Aguadilla-Isabela, PR  310M200US10380
# Akron, OH              310M200US10420
# Albany, GA             310M200US10500
# Albany, OR             310M200US10540
#
#                        Total!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                   131984
# Aguadilla-Isabela, PR                                         265643
# Akron, OH                                                     570055
# Albany, GA                                                    121559
# Albany, OR                                                     93268
#
#                        In labor force!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                         59.3
# Aguadilla-Isabela, PR                                               40.1
# Akron, OH                                                           65.5
# Albany, GA                                                          58.3
# Albany, OR                                                          58.1
#
#                        Employed!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                        53.3
# Aguadilla-Isabela, PR                                              30.0
# Akron, OH                                                          59.1
# Albany, GA                                                         49.3
# Albany, OR                                                         51.5
#
#                        Unemployment rate!!Estimate!!Population 16 years and over  \
# Geographic Area Name
# Abilene, TX                                                          6.4
# Aguadilla-Isabela, PR                                               25.2
# Akron, OH                                                            9.7
# Albany, GA                                                          15.0
# Albany, OR                                                          11.2
#
#                        Total!!Estimate!!AGE!!16 to 19 years  \
# Geographic Area Name
# Abilene, TX                                           10188
# Aguadilla-Isabela, PR                                 19232
# Akron, OH                                             41457
# Albany, GA                                             9505
# Albany, OR                                             5635
#
#                        In labor force!!Estimate!!AGE!!16 to 19 years  \
# Geographic Area Name
# Abilene, TX                                                     41.2
# Aguadilla-Isabela, PR                                           14.0
# Akron, OH                                                       46.3
# Albany, GA                                                      38.0
# Albany, OR                                                      38.9
#
#                        Employed!!Estimate!!AGE!!16 to 19 years  \
# Geographic Area Name
# Abilene, TX                                               33.0
# Aguadilla-Isabela, PR                                      3.9
# Akron, OH                                                 32.4
# Albany, GA                                                24.4
# Albany, OR                                                26.5
#
#                        Unemployment rate!!Estimate!!AGE!!16 to 19 years  \
# Geographic Area Name
# Abilene, TX                                                        18.0
# Aguadilla-Isabela, PR                                              71.9
# Akron, OH                                                          30.0
# Albany, GA                                                         35.8
# Albany, OR                                                         32.0
#
#                        Total!!Estimate!!AGE!!20 to 24 years  ...  \
# Geographic Area Name                                         ...
# Abilene, TX                                           16573  ...
# Aguadilla-Isabela, PR                                 22522  ...
# Akron, OH                                             53561  ...
# Albany, GA                                            12284  ...
# Albany, OR                                             7220  ...
#
#                        Employed!!Estimate!!AGE!!75 years and over  \
# Geographic Area Name
# Abilene, TX                                                   8.1
# Aguadilla-Isabela, PR                                         1.4
# Akron, OH                                                     5.2
# Albany, GA                                                    4.6
# Albany, OR                                                    4.1
#
#                        Unemployment rate!!Estimate!!AGE!!75 years and over  \
# Geographic Area Name
# Abilene, TX                                                          1.5
# Aguadilla-Isabela, PR                                                0.0
# Akron, OH                                                            8.7
# Albany, GA                                                           2.0
# Albany, OR                                                          10.1
#
#                        Total!!Estimate!!Population 20 to 64 years  \
# Geographic Area Name
# Abilene, TX                                                 98352
# Aguadilla-Isabela, PR                                      192817
# Akron, OH                                                  423341
# Albany, GA                                                  91862
# Albany, OR                                                  68465
#
#                        In labor force!!Estimate!!Population 20 to 64 years  \
# Geographic Area Name
# Abilene, TX                                                         70.9
# Aguadilla-Isabela, PR                                               52.9
# Akron, OH                                                           79.6
# Albany, GA                                                          70.4
# Albany, OR                                                          72.6
#
#                        Employed!!Estimate!!Population 20 to 64 years  \
# Geographic Area Name
# Abilene, TX                                                     63.8
# Aguadilla-Isabela, PR                                           39.9
# Akron, OH                                                       72.6
# Albany, GA                                                      60.1
# Albany, OR                                                      64.8
#
#                        Unemployment rate!!Estimate!!Population 20 to 64 years  \
# Geographic Area Name
# Abilene, TX                                                          6.0
# Aguadilla-Isabela, PR                                               24.4
# Akron, OH                                                            8.7
# Albany, GA                                                          14.1
# Albany, OR                                                          10.5
#
#                        Total!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# Geographic Area Name
# Abilene, TX                                                        15289
# Aguadilla-Isabela, PR                                              97143
# Akron, OH                                                          59727
# Albany, GA                                                         20909
# Albany, OR                                                         12147
#
#                        In labor force!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# Geographic Area Name
# Abilene, TX                                                         52.3
# Aguadilla-Isabela, PR                                               42.0
# Akron, OH                                                           57.3
# Albany, GA                                                          50.3
# Albany, OR                                                          48.8
#
#                        Employed!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level  \
# Geographic Area Name
# Abilene, TX                                                         41.7
# Aguadilla-Isabela, PR                                               23.4
# Akron, OH                                                           38.2
# Albany, GA                                                          29.6
# Albany, OR                                                          33.9
#
#                        Unemployment rate!!Estimate!!POVERTY STATUS IN THE PAST 12 MONTHS!!Below poverty level
# Geographic Area Name
# Abilene, TX                                                         19.6
# Aguadilla-Isabela, PR                                               44.3
# Akron, OH                                                           33.3
# Albany, GA                                                          41.1
# Albany, OR                                                          30.4
#
# [5 rows x 41 columns]

# %%
### Create empty dataframe with ACS MSA names as index:
#po_df = pd.DataFrame(index = pop_df.index)

# %%
employment_rate = pop_df['Employed!!Estimate!!Population 16 years and over']

# %%
employment_rate
# Out:
# Geographic Area Name
# Abilene, TX                          53.3
# Aguadilla-Isabela, PR                30.0
# Akron, OH                            59.1
# Albany, GA                           49.3
# Albany, OR                           51.5
#                                      ...
# Yakima, WA                           55.7
# York-Hanover, PA                     61.7
# Youngstown-Warren-Boardman, OH-PA    52.3
# Yuba City, CA                        49.0
# Yuma, AZ                             46.0
# Name: Employed!!Estimate!!Population 16 years and over, Length: 388, dtype: float64

# %%
unemployment_rate_check = 100 - employment_rate

# %%
unemployment_rate_check
# Out:
# Geographic Area Name
# Abilene, TX                          46.7
# Aguadilla-Isabela, PR                70.0
# Akron, OH                            40.9
# Albany, GA                           50.7
# Albany, OR                           48.5
#                                      ...
# Yakima, WA                           44.3
# York-Hanover, PA                     38.3
# Youngstown-Warren-Boardman, OH-PA    47.7
# Yuba City, CA                        51.0
# Yuma, AZ                             54.0
# Name: Employed!!Estimate!!Population 16 years and over, Length: 388, dtype: float64

# %%
#Does not match unemployment check

unemployment_rate = pop_df['Unemployment rate!!Estimate!!Population 16 years and over']

# %%
unemployment_rate
# Out:
# Geographic Area Name
# Abilene, TX                           6.4
# Aguadilla-Isabela, PR                25.2
# Akron, OH                             9.7
# Albany, GA                           15.0
# Albany, OR                           11.2
#                                      ...
# Yakima, WA                           10.0
# York-Hanover, PA                      8.3
# Youngstown-Warren-Boardman, OH-PA     9.4
# Yuba City, CA                        15.4
# Yuma, AZ                             13.4
# Name: Unemployment rate!!Estimate!!Population 16 years and over, Length: 388, dtype: float64

# %%
#pop_df.to_csv('data-aggregation-pop.csv', index = False)
from pathlib import Path  
filepath = Path('../../data/tidy/data-aggregation-pop.csv', index = False)  
filepath.parent.mkdir(parents=True, exist_ok=True)  
pop_df.to_csv(filepath)
